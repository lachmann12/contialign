# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

import os

# %%
pp = "/Users/maayanlab/Documents/GitHub/contialign/varconti/"
os.chdir(pp)

# %%
kallisto = pd.read_csv("../output/kallisto/abundance.tsv", sep="\t")
kallisto = kallisto.set_index("target_id")
kallisto_length = kallisto.iloc[:,2]
kallisto = kallisto.iloc[:,3]

conti = pd.read_csv("../output/counts3.tsv", sep="\t", header=None)
conti = conti.set_index(0)

# %%
inter = kallisto.index.intersection(conti.index)

# %%
plt.scatter(np.log(conti.loc[inter]+1), np.log(kallisto.loc[inter]+1), s=0.2)
plt.xlabel("Conti")
plt.ylabel("Kallisto")
np.corrcoef(np.log(conti.loc[inter].iloc[:,0]+1), np.log(kallisto.loc[inter]+1))
# Out:
# array([[1.        , 0.63099916],
#        [0.63099916, 1.        ]])

# %%
c = conti.loc[inter].iloc[:,0]
k = kallisto.loc[inter]

diff = c-k
diff = diff.sort_values()
np.log2(5)
# Out:
# 2.321928094887362

# %%
plt.scatter(np.log(1+kallisto_length.loc[inter]), np.log2(1+np.abs(diff.loc[inter])), s=0.3)
